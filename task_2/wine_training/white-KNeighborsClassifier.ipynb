# %%
# Env
import os
from dotenv import load_dotenv
if not load_dotenv() or 'HOPSWORKS_API_KEY' not in os.environ:
    print("Please provide a .env file add HOPSWORKS_API_KEY to it.")
    exit(1)

# No warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')  # "error", "ignore", "always", "default", "module" or "once"

# Imports
import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
import hopsworks
import pandas as pd
import numpy as np
import math

# Heavy operation cache
from IPython.display import Image
from pathlib import Path
dir_plot_saves = "./plots"
# - Plots
Path(dir_plot_saves).mkdir(parents=True, exist_ok=True)
# Plot cache
def plot_or_cache(plotting_function, plot_name):
    plot_destination = f"{dir_plot_saves}/{plot_name}.png"
    if os.path.isfile(plot_destination):
        display(Image(filename=plot_destination))
    else:
        plotting_function()
        plt.savefig(plot_destination)
        plt.show()

# My help commands
from wine_training_help import evaluate_pca, train_evaluation

# 
import json
from hsfs.client.exceptions import RestAPIError

# IDE help
from hsfs import feature_store, feature_group, feature_view
from hsfs.constructor import query as hsfs_query

# Names
# - Models
model_red_wine_name = "wine_red_model"
model_red_wine_version = 1
model_white_wine_name = "wine_white_model"
model_white_wine_version = 1
# - Feature Groups
fg_wine_name = "wine"
fg_wine_version = 1
# fg_red_wine_name = "wine_red"
# fg_red_wine_version = 1
# fg_white_wine_name = "wine_white"
# fg_white_wine_version = 1
fg_type_red = "red"
fg_type_white = "white"

# %%
# Log in to Hopsworks and get feature store
project = hopsworks.login()
fs = project.get_feature_store()
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/201877
# Connected. Call `.close()` to terminate connection gracefully.

# %%
try:
    wine_fg: feature_group.FeatureGroup = fs.get_feature_group(name=fg_wine_name, version=fg_wine_version)
    print(f"Wine data (version: {fg_wine_version}) gotten!")
except RestAPIError as e:
    try:
        response_json = json.loads(e.response.content)
    except Exception:
        response_json = []
    
    if "errorMsg" in response_json and response_json["errorMsg"] == "Featuregroup wasn\'t found.":
        print(f"Wine (version: {fg_wine_version}) does not exist on Hopsworks. (upload it first)")
        
    else:
        raise Exception(f"An unexpected RestAPIError happened: {e.response.content}")
except Exception as e:
    raise Exception(f"Something unexpected happened: {e}")
# Out:
# Wine data (version: 1) gotten!

# %%
wine_query: hsfs_query.Query = wine_fg.select_all()
wine_query

# %%
wine_df: pd.DataFrame = wine_query.read()
wine_white_df = wine_df[wine_df["type"] == fg_type_white]
wine_white_df = wine_white_df.drop(columns=["type"])
wine_white_df
# Out:
# Finished: Reading data from Hopsworks, using ArrowFlight (1.17s)
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               6.8              0.21         0.55           14.60      0.053
# 1               7.0              0.39         0.31            5.30      0.169
# 3               6.3              0.23         0.33            1.50      0.036
# 4               7.0              0.29         0.37            4.90      0.034
# 5               7.3              0.24         0.43            2.00      0.021
# ...             ...               ...          ...             ...        ...
# 5313            6.7              0.29         0.49            4.70      0.034
# 5314            6.0              0.22         0.28            1.10      0.034
# 5315            6.6              0.22         0.35            1.40      0.050
# 5316            6.5              0.43         0.18           13.15      0.032
# 5317            8.8              0.36         0.44            1.90      0.040
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# 0                    34.0                 159.0  0.99805  2.93       0.44
# 1                    32.0                 162.0  0.99650  3.20       0.48
# 3                    15.0                 105.0  0.99100  3.32       0.42
# 4                    26.0                 127.0  0.99280  3.17       0.44
# 5                    20.0                  69.0  0.99000  3.08       0.56
# ...                   ...                   ...      ...   ...        ...
# 5313                 35.0                 156.0  0.99450  3.13       0.45
# 5314                 47.0                  90.0  0.98862  3.22       0.38
# 5315                 23.0                  83.0  0.99019  3.17       0.48
# 5316                 25.0                 131.0  0.99565  3.23       0.51
# 5317                  9.0                 121.0  0.99530  3.19       0.48
#
#       alcohol  quality
# 0         9.2        5
# 1         9.4        5
# 3        11.2        6
# 4        10.8        6
# 5        12.2        6
# ...       ...      ...
# 5313      9.9        6
# 5314     12.6        6
# 5315     12.0        7
# 5316     10.7        5
# 5317      9.9        6
#
# [3961 rows x 12 columns]

# %% [markdown]
# # PCA

# %%
evaluate_pca(wine_white_df)

# %% [markdown]
# https://scribe.rip/@sanchitamangale12/scree-plot-733ed72c8608
#
# If we should keep at least 80% of the total variance in the original dataset. Then it seems good to try 4-6 for the white wine.

# %%
# Try to look for best n_neighbors using cross validation
train_evaluation(wine_white_df, 'quality', use_model="KNeighborsClassifier")
# Out:
# No 'n_neighbors' set. Looking for best value...
# Optimal number of neighbors: 39
# 39

# %%
# A KNN model with 37 neighbors might rarely predict the minority classes (3, 8 and 9) correctly.
# Also, very weird when the number of samples are so low... Cannot use 37...

# %%
def brute_force_check_KNeighborsClassifier():
    df_acc = pd.DataFrame(columns=['PCA','n_neighbors','Resample','Accuracy'])
    
    for i in [False] + list(range(4, 7)):
        for j in list(range(1, 9, 2)) + list(range(37 - 4, 37 + 4 + 1, 2)):
            for k in [False, "undersample", "oversample", "smote"]:
                cur_accuracy = train_evaluation(
                    wine_white_df, 'quality', use_model="KNeighborsClassifier", 
                    use_pca_n_components=i,
                    use_resampler=k, class_knn_n_neighbors=j,
                    silent=True)
                print(f"Checked: PCA {i}, n_neighbors {j}, resample {k} -> {cur_accuracy}%")
                
                df_acc.loc[len(df_acc.index)] = [i, j, k, cur_accuracy]

    display(df_acc.sort_values(by='Accuracy', ascending=False))
    
brute_force_check_KNeighborsClassifier()
# Out:
# Checked: PCA False, n_neighbors 1, resample False -> 0.5132408575031526%
# Checked: PCA False, n_neighbors 1, resample undersample -> 0.22698612862547288%
# Checked: PCA False, n_neighbors 1, resample oversample -> 0.4968474148802018%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA False, n_neighbors 1, resample smote -> 0%
# Checked: PCA False, n_neighbors 3, resample False -> 0.47162673392181587%
# Checked: PCA False, n_neighbors 3, resample undersample -> 0.21059268600252207%
# Checked: PCA False, n_neighbors 3, resample oversample -> 0.43883984867591425%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA False, n_neighbors 3, resample smote -> 0%
# Checked: PCA False, n_neighbors 5, resample False -> 0.48675914249684743%
# Checked: PCA False, n_neighbors 5, resample undersample -> 0.21185372005044137%
# Checked: PCA False, n_neighbors 5, resample oversample -> 0.4300126103404792%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA False, n_neighbors 5, resample smote -> 0%
# Checked: PCA False, n_neighbors 7, resample False -> 0.501891551071879%
# Checked: PCA False, n_neighbors 7, resample undersample -> 0.22950819672131148%
# Checked: PCA False, n_neighbors 7, resample oversample -> 0.41992433795712486%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA False, n_neighbors 7, resample smote -> 0%
# Checked: PCA False, n_neighbors 33, resample False -> 0.5548549810844893%
# Cannot use KNeighborsClassifier with n_neighbors=33 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 33
# Checked: PCA False, n_neighbors 33, resample undersample -> 0%
# Checked: PCA False, n_neighbors 33, resample oversample -> 0.3467843631778058%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA False, n_neighbors 33, resample smote -> 0%
# Checked: PCA False, n_neighbors 35, resample False -> 0.5523329129886507%
# Cannot use KNeighborsClassifier with n_neighbors=35 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 35
# Checked: PCA False, n_neighbors 35, resample undersample -> 0%
# Checked: PCA False, n_neighbors 35, resample oversample -> 0.3455233291298865%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA False, n_neighbors 35, resample smote -> 0%
# Checked: PCA False, n_neighbors 37, resample False -> 0.5472887767969735%
# Cannot use KNeighborsClassifier with n_neighbors=37 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 37
# Checked: PCA False, n_neighbors 37, resample undersample -> 0%
# Checked: PCA False, n_neighbors 37, resample oversample -> 0.35435056746532156%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA False, n_neighbors 37, resample smote -> 0%
# Checked: PCA False, n_neighbors 39, resample False -> 0.5548549810844893%
# Cannot use KNeighborsClassifier with n_neighbors=39 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 39
# Checked: PCA False, n_neighbors 39, resample undersample -> 0%
# Checked: PCA False, n_neighbors 39, resample oversample -> 0.35687263556116017%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA False, n_neighbors 39, resample smote -> 0%
# Checked: PCA False, n_neighbors 41, resample False -> 0.5535939470365699%
# Cannot use KNeighborsClassifier with n_neighbors=41 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 41
# Checked: PCA False, n_neighbors 41, resample undersample -> 0%
# Checked: PCA False, n_neighbors 41, resample oversample -> 0.3656998738965952%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA False, n_neighbors 41, resample smote -> 0%
# Checked: PCA 4, n_neighbors 1, resample False -> 0.4640605296343001%
# Checked: PCA 4, n_neighbors 1, resample undersample -> 0.22698612862547288%
# Checked: PCA 4, n_neighbors 1, resample oversample -> 0.4640605296343001%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 4, n_neighbors 1, resample smote -> 0%
# Checked: PCA 4, n_neighbors 3, resample False -> 0.44640605296343%
# Checked: PCA 4, n_neighbors 3, resample undersample -> 0.21563682219419925%
# Checked: PCA 4, n_neighbors 3, resample oversample -> 0.40226986128625475%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 4, n_neighbors 3, resample smote -> 0%
# Checked: PCA 4, n_neighbors 5, resample False -> 0.49558638083228246%
# Checked: PCA 4, n_neighbors 5, resample undersample -> 0.21689785624211855%
# Checked: PCA 4, n_neighbors 5, resample oversample -> 0.3883984867591425%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 4, n_neighbors 5, resample smote -> 0%
# Checked: PCA 4, n_neighbors 7, resample False -> 0.5031525851197982%
# Checked: PCA 4, n_neighbors 7, resample undersample -> 0.19924337957124844%
# Checked: PCA 4, n_neighbors 7, resample oversample -> 0.38461538461538464%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 4, n_neighbors 7, resample smote -> 0%
# Checked: PCA 4, n_neighbors 33, resample False -> 0.501891551071879%
# Cannot use KNeighborsClassifier with n_neighbors=33 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 33
# Checked: PCA 4, n_neighbors 33, resample undersample -> 0%
# Checked: PCA 4, n_neighbors 33, resample oversample -> 0.29508196721311475%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 4, n_neighbors 33, resample smote -> 0%
# Checked: PCA 4, n_neighbors 35, resample False -> 0.5094577553593947%
# Cannot use KNeighborsClassifier with n_neighbors=35 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 35
# Checked: PCA 4, n_neighbors 35, resample undersample -> 0%
# Checked: PCA 4, n_neighbors 35, resample oversample -> 0.30012610340479196%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 4, n_neighbors 35, resample smote -> 0%
# Checked: PCA 4, n_neighbors 37, resample False -> 0.5056746532156369%
# Cannot use KNeighborsClassifier with n_neighbors=37 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 37
# Checked: PCA 4, n_neighbors 37, resample undersample -> 0%
# Checked: PCA 4, n_neighbors 37, resample oversample -> 0.3064312736443884%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 4, n_neighbors 37, resample smote -> 0%
# Checked: PCA 4, n_neighbors 39, resample False -> 0.5044136191677175%
# Cannot use KNeighborsClassifier with n_neighbors=39 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 39
# Checked: PCA 4, n_neighbors 39, resample undersample -> 0%
# Checked: PCA 4, n_neighbors 39, resample oversample -> 0.31021437578814626%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 4, n_neighbors 39, resample smote -> 0%
# Checked: PCA 4, n_neighbors 41, resample False -> 0.5069356872635561%
# Cannot use KNeighborsClassifier with n_neighbors=41 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 41
# Checked: PCA 4, n_neighbors 41, resample undersample -> 0%
# Checked: PCA 4, n_neighbors 41, resample oversample -> 0.296343001261034%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 4, n_neighbors 41, resample smote -> 0%
# Checked: PCA 5, n_neighbors 1, resample False -> 0.4943253467843632%
# Checked: PCA 5, n_neighbors 1, resample undersample -> 0.223203026481715%
# Checked: PCA 5, n_neighbors 1, resample oversample -> 0.4943253467843632%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 5, n_neighbors 1, resample smote -> 0%
# Checked: PCA 5, n_neighbors 3, resample False -> 0.48045397225725095%
# Checked: PCA 5, n_neighbors 3, resample undersample -> 0.23076923076923078%
# Checked: PCA 5, n_neighbors 3, resample oversample -> 0.4401008827238335%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 5, n_neighbors 3, resample smote -> 0%
# Checked: PCA 5, n_neighbors 5, resample False -> 0.5044136191677175%
# Checked: PCA 5, n_neighbors 5, resample undersample -> 0.20933165195460277%
# Checked: PCA 5, n_neighbors 5, resample oversample -> 0.424968474148802%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 5, n_neighbors 5, resample smote -> 0%
# Checked: PCA 5, n_neighbors 7, resample False -> 0.5119798234552333%
# Checked: PCA 5, n_neighbors 7, resample undersample -> 0.21311475409836064%
# Checked: PCA 5, n_neighbors 7, resample oversample -> 0.4136191677175284%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 5, n_neighbors 7, resample smote -> 0%
# Checked: PCA 5, n_neighbors 33, resample False -> 0.5346784363177806%
# Cannot use KNeighborsClassifier with n_neighbors=33 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 33
# Checked: PCA 5, n_neighbors 33, resample undersample -> 0%
# Checked: PCA 5, n_neighbors 33, resample oversample -> 0.3203026481715006%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 5, n_neighbors 33, resample smote -> 0%
# Checked: PCA 5, n_neighbors 35, resample False -> 0.5359394703656999%
# Cannot use KNeighborsClassifier with n_neighbors=35 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 35
# Checked: PCA 5, n_neighbors 35, resample undersample -> 0%
# Checked: PCA 5, n_neighbors 35, resample oversample -> 0.3253467843631778%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 5, n_neighbors 35, resample smote -> 0%
# Checked: PCA 5, n_neighbors 37, resample False -> 0.5384615384615384%
# Cannot use KNeighborsClassifier with n_neighbors=37 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 37
# Checked: PCA 5, n_neighbors 37, resample undersample -> 0%
# Checked: PCA 5, n_neighbors 37, resample oversample -> 0.3253467843631778%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 5, n_neighbors 37, resample smote -> 0%
# Checked: PCA 5, n_neighbors 39, resample False -> 0.5308953341740227%
# Cannot use KNeighborsClassifier with n_neighbors=39 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 39
# Checked: PCA 5, n_neighbors 39, resample undersample -> 0%
# Checked: PCA 5, n_neighbors 39, resample oversample -> 0.3291298865069357%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 5, n_neighbors 39, resample smote -> 0%
# Checked: PCA 5, n_neighbors 41, resample False -> 0.532156368221942%
# Cannot use KNeighborsClassifier with n_neighbors=41 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 41
# Checked: PCA 5, n_neighbors 41, resample undersample -> 0%
# Checked: PCA 5, n_neighbors 41, resample oversample -> 0.31525851197982346%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 5, n_neighbors 41, resample smote -> 0%
# Checked: PCA 6, n_neighbors 1, resample False -> 0.48045397225725095%
# Checked: PCA 6, n_neighbors 1, resample undersample -> 0.2257250945775536%
# Checked: PCA 6, n_neighbors 1, resample oversample -> 0.48045397225725095%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 6, n_neighbors 1, resample smote -> 0%
# Checked: PCA 6, n_neighbors 3, resample False -> 0.4728877679697352%
# Checked: PCA 6, n_neighbors 3, resample undersample -> 0.23707440100882723%
# Checked: PCA 6, n_neighbors 3, resample oversample -> 0.4337957124842371%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 6, n_neighbors 3, resample smote -> 0%
# Checked: PCA 6, n_neighbors 5, resample False -> 0.4930643127364439%
# Checked: PCA 6, n_neighbors 5, resample undersample -> 0.19798234552332913%
# Checked: PCA 6, n_neighbors 5, resample oversample -> 0.4224464060529634%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 6, n_neighbors 5, resample smote -> 0%
# Checked: PCA 6, n_neighbors 7, resample False -> 0.5132408575031526%
# Checked: PCA 6, n_neighbors 7, resample undersample -> 0.21185372005044137%
# Checked: PCA 6, n_neighbors 7, resample oversample -> 0.39344262295081966%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 6, n_neighbors 7, resample smote -> 0%
# Checked: PCA 6, n_neighbors 33, resample False -> 0.5435056746532156%
# Cannot use KNeighborsClassifier with n_neighbors=33 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 33
# Checked: PCA 6, n_neighbors 33, resample undersample -> 0%
# Checked: PCA 6, n_neighbors 33, resample oversample -> 0.34300126103404793%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 6, n_neighbors 33, resample smote -> 0%
# Checked: PCA 6, n_neighbors 35, resample False -> 0.5485498108448928%
# Cannot use KNeighborsClassifier with n_neighbors=35 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 35
# Checked: PCA 6, n_neighbors 35, resample undersample -> 0%
# Checked: PCA 6, n_neighbors 35, resample oversample -> 0.3442622950819672%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 6, n_neighbors 35, resample smote -> 0%
# Checked: PCA 6, n_neighbors 37, resample False -> 0.5485498108448928%
# Cannot use KNeighborsClassifier with n_neighbors=37 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 37
# Checked: PCA 6, n_neighbors 37, resample undersample -> 0%
# Checked: PCA 6, n_neighbors 37, resample oversample -> 0.33921815889029006%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 6, n_neighbors 37, resample smote -> 0%
# Checked: PCA 6, n_neighbors 39, resample False -> 0.5435056746532156%
# Cannot use KNeighborsClassifier with n_neighbors=39 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 39
# Checked: PCA 6, n_neighbors 39, resample undersample -> 0%
# Checked: PCA 6, n_neighbors 39, resample oversample -> 0.3329129886506936%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 6, n_neighbors 39, resample smote -> 0%
# Checked: PCA 6, n_neighbors 41, resample False -> 0.5346784363177806%
# Cannot use KNeighborsClassifier with n_neighbors=41 on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 28, n_neighbors = 41
# Checked: PCA 6, n_neighbors 41, resample undersample -> 0%
# Checked: PCA 6, n_neighbors 41, resample oversample -> 0.33669609079445145%
# Cannot use SMOTE on dataset! Got error: Expected n_neighbors <= n_samples,  but n_samples = 4, n_neighbors = 6
# Checked: PCA 6, n_neighbors 41, resample smote -> 0%
#      PCA  n_neighbors     Resample  Accuracy
# 28     0           39        False  0.554855
# 16     0           33        False  0.554855
# 32     0           41        False  0.553594
# 20     0           35        False  0.552333
# 132    6           37        False  0.548550
# ..   ...          ...          ...       ...
# 79     5            3        smote  0.000000
# 75     5            1        smote  0.000000
# 71     4           41        smote  0.000000
# 69     4           41  undersample  0.000000
# 143    6           41        smote  0.000000
#
# [144 rows x 4 columns]

# %%
# Inspect #1 result with 56%

# %%
for i in range(31, 36, 2):
    print(f"n_neighbors={i}")
    accuracy, df_cm = train_evaluation(
        wine_white_df, 'quality', use_model="KNeighborsClassifier", 
        use_pca_n_components=False,
        use_resampler=False, 
        class_knn_n_neighbors=i)
    plt.figure()
    cm = sns.heatmap(df_cm, annot=True)
    cm.get_figure()
    plt.show()
    print("\n\n")
# Out:
# n_neighbors=31
# Accuracy: 55.49%
# n_neighbors=33
# Accuracy: 55.49%
# n_neighbors=35
# Accuracy: 55.23%

# %%
# Adjusting categories
# It is probably not allowed, but as there are so few high or low ranking wines, 
# it may be difficult to train a model on this data. If the categories are adjusted to: 
# low, medium and high quality wines (just 3 categories), the model might perform better. 
# There are a lot of wines in the 5-6 range. So the categories can be:
# - Low: 0-5
# - Medium: 5-6
# - High: 6-10

# %%
# Try to look for best n_neighbors using cross validation
train_evaluation(
    wine_white_df, 'quality', use_model="KNeighborsClassifier",
    classifier_adjust_categories=((0, 5, 6, 10), ['low', 'medium', 'high']))
# Out:
# No 'n_neighbors' set. Looking for best value...
# Optimal number of neighbors: 41
# 41

# %%
def brute_force_check_KNeighborsClassifier_adjust():
    df_acc = pd.DataFrame(columns=['PCA','n_neighbors','Resample','Accuracy'])
    
    for i in [False] + list(range(4, 7)):
        for j in list(range(1, 9 + 1, 2)) + list(range(53 - 4, 53 + 4 + 1, 2)):
            for k in [False, "undersample", "oversample", "smote"]:
                cur_accuracy = train_evaluation(
                    wine_white_df, 'quality', use_model="KNeighborsClassifier", 
                    classifier_adjust_categories=((0, 5, 6, 10), ['low', 'medium', 'high']),
                    use_pca_n_components=i,
                    use_resampler=k, class_knn_n_neighbors=j,
                    silent=True)
                print(f"Checked: PCA {i}, n_neighbors {j}, resample {k} -> {cur_accuracy}%")
                
                df_acc.loc[len(df_acc.index)] = [i, j, k, cur_accuracy]

    display(df_acc.sort_values(by='Accuracy', ascending=False))
    
brute_force_check_KNeighborsClassifier_adjust()
# Out:
# Checked: PCA False, n_neighbors 1, resample False -> 0.5699873896595208%
# Checked: PCA False, n_neighbors 1, resample undersample -> 0.5069356872635561%
# Checked: PCA False, n_neighbors 1, resample oversample -> 0.562421185372005%
# Checked: PCA False, n_neighbors 1, resample smote -> 0.5662042875157629%
# Checked: PCA False, n_neighbors 3, resample False -> 0.5372005044136192%
# Checked: PCA False, n_neighbors 3, resample undersample -> 0.5006305170239597%
# Checked: PCA False, n_neighbors 3, resample oversample -> 0.5233291298865069%
# Checked: PCA False, n_neighbors 3, resample smote -> 0.5258511979823455%
# Checked: PCA False, n_neighbors 5, resample False -> 0.5296343001261034%
# Checked: PCA False, n_neighbors 5, resample undersample -> 0.5094577553593947%
# Checked: PCA False, n_neighbors 5, resample oversample -> 0.49936948297604034%
# Checked: PCA False, n_neighbors 5, resample smote -> 0.5132408575031526%
# Checked: PCA False, n_neighbors 7, resample False -> 0.5649432534678437%
# Checked: PCA False, n_neighbors 7, resample undersample -> 0.5397225725094578%
# Checked: PCA False, n_neighbors 7, resample oversample -> 0.5397225725094578%
# Checked: PCA False, n_neighbors 7, resample smote -> 0.5498108448928121%
# Checked: PCA False, n_neighbors 9, resample False -> 0.5687263556116016%
# Checked: PCA False, n_neighbors 9, resample undersample -> 0.5510718789407314%
# Checked: PCA False, n_neighbors 9, resample oversample -> 0.5409836065573771%
# Checked: PCA False, n_neighbors 9, resample smote -> 0.5409836065573771%
# Checked: PCA False, n_neighbors 49, resample False -> 0.6166456494325346%
# Checked: PCA False, n_neighbors 49, resample undersample -> 0.5182849936948297%
# Checked: PCA False, n_neighbors 49, resample oversample -> 0.5472887767969735%
# Checked: PCA False, n_neighbors 49, resample smote -> 0.5346784363177806%
# Checked: PCA False, n_neighbors 51, resample False -> 0.6216897856242118%
# Checked: PCA False, n_neighbors 51, resample undersample -> 0.5220680958385876%
# Checked: PCA False, n_neighbors 51, resample oversample -> 0.5384615384615384%
# Checked: PCA False, n_neighbors 51, resample smote -> 0.532156368221942%
# Checked: PCA False, n_neighbors 53, resample False -> 0.6166456494325346%
# Checked: PCA False, n_neighbors 53, resample undersample -> 0.5157629255989912%
# Checked: PCA False, n_neighbors 53, resample oversample -> 0.5409836065573771%
# Checked: PCA False, n_neighbors 53, resample smote -> 0.5283732660781841%
# Checked: PCA False, n_neighbors 55, resample False -> 0.6141235813366961%
# Checked: PCA False, n_neighbors 55, resample undersample -> 0.5271122320302648%
# Checked: PCA False, n_neighbors 55, resample oversample -> 0.5346784363177806%
# Checked: PCA False, n_neighbors 55, resample smote -> 0.5170239596469105%
# Checked: PCA False, n_neighbors 57, resample False -> 0.6153846153846154%
# Checked: PCA False, n_neighbors 57, resample undersample -> 0.5258511979823455%
# Checked: PCA False, n_neighbors 57, resample oversample -> 0.5359394703656999%
# Checked: PCA False, n_neighbors 57, resample smote -> 0.5296343001261034%
# Checked: PCA 4, n_neighbors 1, resample False -> 0.5170239596469105%
# Checked: PCA 4, n_neighbors 1, resample undersample -> 0.48297604035308955%
# Checked: PCA 4, n_neighbors 1, resample oversample -> 0.5170239596469105%
# Checked: PCA 4, n_neighbors 1, resample smote -> 0.5157629255989912%
# Checked: PCA 4, n_neighbors 3, resample False -> 0.49936948297604034%
# Checked: PCA 4, n_neighbors 3, resample undersample -> 0.46153846153846156%
# Checked: PCA 4, n_neighbors 3, resample oversample -> 0.48045397225725095%
# Checked: PCA 4, n_neighbors 3, resample smote -> 0.4842370744010088%
# Checked: PCA 4, n_neighbors 5, resample False -> 0.519546027742749%
# Checked: PCA 4, n_neighbors 5, resample undersample -> 0.4728877679697352%
# Checked: PCA 4, n_neighbors 5, resample oversample -> 0.47162673392181587%
# Checked: PCA 4, n_neighbors 5, resample smote -> 0.4968474148802018%
# Checked: PCA 4, n_neighbors 7, resample False -> 0.5334174022698613%
# Checked: PCA 4, n_neighbors 7, resample undersample -> 0.4842370744010088%
# Checked: PCA 4, n_neighbors 7, resample oversample -> 0.48045397225725095%
# Checked: PCA 4, n_neighbors 7, resample smote -> 0.4930643127364439%
# Checked: PCA 4, n_neighbors 9, resample False -> 0.5233291298865069%
# Checked: PCA 4, n_neighbors 9, resample undersample -> 0.4854981084489281%
# Checked: PCA 4, n_neighbors 9, resample oversample -> 0.4905422446406053%
# Checked: PCA 4, n_neighbors 9, resample smote -> 0.4918032786885246%
# Checked: PCA 4, n_neighbors 49, resample False -> 0.5636822194199244%
# Checked: PCA 4, n_neighbors 49, resample undersample -> 0.4918032786885246%
# Checked: PCA 4, n_neighbors 49, resample oversample -> 0.5119798234552333%
# Checked: PCA 4, n_neighbors 49, resample smote -> 0.5233291298865069%
# Checked: PCA 4, n_neighbors 51, resample False -> 0.5687263556116016%
# Checked: PCA 4, n_neighbors 51, resample undersample -> 0.5006305170239597%
# Checked: PCA 4, n_neighbors 51, resample oversample -> 0.5081967213114754%
# Checked: PCA 4, n_neighbors 51, resample smote -> 0.5208070617906684%
# Checked: PCA 4, n_neighbors 53, resample False -> 0.5674653215636822%
# Checked: PCA 4, n_neighbors 53, resample undersample -> 0.501891551071879%
# Checked: PCA 4, n_neighbors 53, resample oversample -> 0.501891551071879%
# Checked: PCA 4, n_neighbors 53, resample smote -> 0.5132408575031526%
# Checked: PCA 4, n_neighbors 55, resample False -> 0.5699873896595208%
# Checked: PCA 4, n_neighbors 55, resample undersample -> 0.4930643127364439%
# Checked: PCA 4, n_neighbors 55, resample oversample -> 0.5056746532156369%
# Checked: PCA 4, n_neighbors 55, resample smote -> 0.5208070617906684%
# Checked: PCA 4, n_neighbors 57, resample False -> 0.5725094577553594%
# Checked: PCA 4, n_neighbors 57, resample undersample -> 0.4943253467843632%
# Checked: PCA 4, n_neighbors 57, resample oversample -> 0.5056746532156369%
# Checked: PCA 4, n_neighbors 57, resample smote -> 0.5119798234552333%
# Checked: PCA 5, n_neighbors 1, resample False -> 0.5435056746532156%
# Checked: PCA 5, n_neighbors 1, resample undersample -> 0.48675914249684743%
# Checked: PCA 5, n_neighbors 1, resample oversample -> 0.5435056746532156%
# Checked: PCA 5, n_neighbors 1, resample smote -> 0.5283732660781841%
# Checked: PCA 5, n_neighbors 3, resample False -> 0.5220680958385876%
# Checked: PCA 5, n_neighbors 3, resample undersample -> 0.4842370744010088%
# Checked: PCA 5, n_neighbors 3, resample oversample -> 0.501891551071879%
# Checked: PCA 5, n_neighbors 3, resample smote -> 0.4943253467843632%
# Checked: PCA 5, n_neighbors 5, resample False -> 0.5308953341740227%
# Checked: PCA 5, n_neighbors 5, resample undersample -> 0.4943253467843632%
# Checked: PCA 5, n_neighbors 5, resample oversample -> 0.5094577553593947%
# Checked: PCA 5, n_neighbors 5, resample smote -> 0.510718789407314%
# Checked: PCA 5, n_neighbors 7, resample False -> 0.5472887767969735%
# Checked: PCA 5, n_neighbors 7, resample undersample -> 0.5056746532156369%
# Checked: PCA 5, n_neighbors 7, resample oversample -> 0.4905422446406053%
# Checked: PCA 5, n_neighbors 7, resample smote -> 0.5094577553593947%
# Checked: PCA 5, n_neighbors 9, resample False -> 0.5397225725094578%
# Checked: PCA 5, n_neighbors 9, resample undersample -> 0.4918032786885246%
# Checked: PCA 5, n_neighbors 9, resample oversample -> 0.5132408575031526%
# Checked: PCA 5, n_neighbors 9, resample smote -> 0.5233291298865069%
# Checked: PCA 5, n_neighbors 49, resample False -> 0.5939470365699874%
# Checked: PCA 5, n_neighbors 49, resample undersample -> 0.5094577553593947%
# Checked: PCA 5, n_neighbors 49, resample oversample -> 0.5245901639344263%
# Checked: PCA 5, n_neighbors 49, resample smote -> 0.5258511979823455%
# Checked: PCA 5, n_neighbors 51, resample False -> 0.5939470365699874%
# Checked: PCA 5, n_neighbors 51, resample undersample -> 0.5069356872635561%
# Checked: PCA 5, n_neighbors 51, resample oversample -> 0.5308953341740227%
# Checked: PCA 5, n_neighbors 51, resample smote -> 0.5245901639344263%
# Checked: PCA 5, n_neighbors 53, resample False -> 0.5939470365699874%
# Checked: PCA 5, n_neighbors 53, resample undersample -> 0.5145018915510718%
# Checked: PCA 5, n_neighbors 53, resample oversample -> 0.5296343001261034%
# Checked: PCA 5, n_neighbors 53, resample smote -> 0.5283732660781841%
# Checked: PCA 5, n_neighbors 55, resample False -> 0.5989911727616646%
# Checked: PCA 5, n_neighbors 55, resample undersample -> 0.5157629255989912%
# Checked: PCA 5, n_neighbors 55, resample oversample -> 0.5271122320302648%
# Checked: PCA 5, n_neighbors 55, resample smote -> 0.5258511979823455%
# Checked: PCA 5, n_neighbors 57, resample False -> 0.5914249684741488%
# Checked: PCA 5, n_neighbors 57, resample undersample -> 0.510718789407314%
# Checked: PCA 5, n_neighbors 57, resample oversample -> 0.5258511979823455%
# Checked: PCA 5, n_neighbors 57, resample smote -> 0.5308953341740227%
# Checked: PCA 6, n_neighbors 1, resample False -> 0.5334174022698613%
# Checked: PCA 6, n_neighbors 1, resample undersample -> 0.501891551071879%
# Checked: PCA 6, n_neighbors 1, resample oversample -> 0.5334174022698613%
# Checked: PCA 6, n_neighbors 1, resample smote -> 0.5271122320302648%
# Checked: PCA 6, n_neighbors 3, resample False -> 0.5182849936948297%
# Checked: PCA 6, n_neighbors 3, resample undersample -> 0.489281210592686%
# Checked: PCA 6, n_neighbors 3, resample oversample -> 0.5069356872635561%
# Checked: PCA 6, n_neighbors 3, resample smote -> 0.5094577553593947%
# Checked: PCA 6, n_neighbors 5, resample False -> 0.5220680958385876%
# Checked: PCA 6, n_neighbors 5, resample undersample -> 0.4930643127364439%
# Checked: PCA 6, n_neighbors 5, resample oversample -> 0.5031525851197982%
# Checked: PCA 6, n_neighbors 5, resample smote -> 0.5056746532156369%
# Checked: PCA 6, n_neighbors 7, resample False -> 0.5422446406052963%
# Checked: PCA 6, n_neighbors 7, resample undersample -> 0.5069356872635561%
# Checked: PCA 6, n_neighbors 7, resample oversample -> 0.4968474148802018%
# Checked: PCA 6, n_neighbors 7, resample smote -> 0.5056746532156369%
# Checked: PCA 6, n_neighbors 9, resample False -> 0.5397225725094578%
# Checked: PCA 6, n_neighbors 9, resample undersample -> 0.501891551071879%
# Checked: PCA 6, n_neighbors 9, resample oversample -> 0.510718789407314%
# Checked: PCA 6, n_neighbors 9, resample smote -> 0.49936948297604034%
# Checked: PCA 6, n_neighbors 49, resample False -> 0.5725094577553594%
# Checked: PCA 6, n_neighbors 49, resample undersample -> 0.5170239596469105%
# Checked: PCA 6, n_neighbors 49, resample oversample -> 0.5283732660781841%
# Checked: PCA 6, n_neighbors 49, resample smote -> 0.5308953341740227%
# Checked: PCA 6, n_neighbors 51, resample False -> 0.5851197982345523%
# Checked: PCA 6, n_neighbors 51, resample undersample -> 0.5056746532156369%
# Checked: PCA 6, n_neighbors 51, resample oversample -> 0.5334174022698613%
# Checked: PCA 6, n_neighbors 51, resample smote -> 0.5283732660781841%
# Checked: PCA 6, n_neighbors 53, resample False -> 0.5851197982345523%
# Checked: PCA 6, n_neighbors 53, resample undersample -> 0.5145018915510718%
# Checked: PCA 6, n_neighbors 53, resample oversample -> 0.5233291298865069%
# Checked: PCA 6, n_neighbors 53, resample smote -> 0.5208070617906684%
# Checked: PCA 6, n_neighbors 55, resample False -> 0.5863808322824716%
# Checked: PCA 6, n_neighbors 55, resample undersample -> 0.5145018915510718%
# Checked: PCA 6, n_neighbors 55, resample oversample -> 0.519546027742749%
# Checked: PCA 6, n_neighbors 55, resample smote -> 0.5296343001261034%
# Checked: PCA 6, n_neighbors 57, resample False -> 0.5851197982345523%
# Checked: PCA 6, n_neighbors 57, resample undersample -> 0.5145018915510718%
# Checked: PCA 6, n_neighbors 57, resample oversample -> 0.5258511979823455%
# Checked: PCA 6, n_neighbors 57, resample smote -> 0.5359394703656999%
#     PCA  n_neighbors     Resample  Accuracy
# 24    0           51        False  0.621690
# 28    0           53        False  0.616646
# 20    0           49        False  0.616646
# 36    0           57        False  0.615385
# 32    0           55        False  0.614124
# ..  ...          ...          ...       ...
# 46    4            3   oversample  0.480454
# 54    4            7   oversample  0.480454
# 49    4            5  undersample  0.472888
# 50    4            5   oversample  0.471627
# 45    4            3  undersample  0.461538
#
# [160 rows x 4 columns]

# %%
# Inspect #1 result with 62%

# %%
for i in range(53, 58, 2):
    print(f"n_neighbors={i}")
    accuracy, df_cm = train_evaluation(
        wine_white_df, 'quality', use_model="KNeighborsClassifier", 
        classifier_adjust_categories=((0, 5, 6, 10), ['low', 'medium', 'high']),
        use_pca_n_components=False,
        use_resampler=False, 
        class_knn_n_neighbors=i)
    plt.figure()
    cm = sns.heatmap(df_cm, annot=True)
    cm.get_figure()
    plt.show()
    print("\n\n")
# Out:
# n_neighbors=53
# Accuracy: 61.66%
# n_neighbors=55
# Accuracy: 61.41%
# n_neighbors=57
# Accuracy: 61.54%
